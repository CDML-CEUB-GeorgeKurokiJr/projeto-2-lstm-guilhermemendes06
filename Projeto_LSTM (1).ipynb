# %% [markdown]
# # Projeto: Influência do Dólar no Comportamento de Empresas Brasileiras com LSTM
#
# ### **Objetivo**
#
# Este trabalho tem como finalidade aplicar técnicas de Deep Learning, mais especificamente redes LSTM, para analisar como a variação do dólar pode influenciar o comportamento de empresas brasileiras listadas na bolsa.
#
# Para isso, foram escolhidas duas empresas com características distintas:
#
# Petrobras, representando o setor de energia e exportação
# Magazine Luiza, representando o setor de varejo
#
# A ideia principal é entender como cada uma reage às mudanças no câmbio.
#
# ### **Hipótese**
#
# Parte-se do pressuposto de que o dólar não afeta todas as empresas da mesma forma.
#
# No caso do varejo, o aumento do dólar tende a elevar custos, impactando negativamente
# Já empresas exportadoras podem se beneficiar, pois suas receitas estão ligadas ao mercado externo
#
# Além disso, busca-se verificar se um modelo LSTM consegue identificar esse comportamento nos dados.

# %% [markdown]
# ## 1. Preparação do ambiente
# Finalidade:
#
# Carregar bibliotecas necessárias para análise, manipulação de dados e construção do modelo.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# ## 2. Obtenção dos dados
# Finalidade:
#
# Coletar dados históricos diretamente do mercado financeiro.

# %%
ativos = ["PETR4.SA", "MGLU3.SA", "USDBRL=X"]

dados = yf.download(ativos, start="2018-01-01")["Close"]

dados.dropna(inplace=True)

dados.columns = ["petrobras", "magalu", "dolar"]

dados.head()
# Out:
# /tmp/ipykernel_55134/2064919725.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   dados = yf.download(ativos, start="2018-01-01")["Close"]
# [*********************100%***********************]  3 of 3 completed
#             petrobras    magalu   dolar
# Date
# 2018-01-02  21.134989  4.409358  3.3110
# 2018-01-03  20.868471  4.449322  3.2578
# 2018-01-04  21.369524  4.457315  3.2355
# 2018-01-05  20.948425  4.483959  3.2331
# 2018-01-08  20.951088  4.537242  3.2266

# %% [markdown]
# A escolha dessas variáveis permite comparar empresas com comportamentos potencialmente opostos em relação ao câmbio.

# %% [markdown]
# ## 3. Criação de variáveis adicionais
# Finalidade:
#
# Enriquecer o conjunto de dados com informações que ajudam o modelo a identificar padrões.

# %%
for col in dados.columns:
    dados[f"{col}_SMA"] = dados[col].rolling(10).mean()
    dados[f"{col}_EMA"] = dados[col].ewm(span=10).mean()

    delta = dados[col].diff()
    ganho = (delta.where(delta > 0, 0)).rolling(10).mean()
    perda = (-delta.where(delta < 0, 0)).rolling(10).mean()
    rs = ganho / perda
    dados[f"{col}_RSI"] = 100 - (100 / (1 + rs))

dados.dropna(inplace=True)

# %% [markdown]
# Esses indicadores ajudam a capturar tendência e comportamento do mercado ao longo do tempo.

# %% [markdown]
# ## 4. Análise inicial
# Finalidade:
#
# Visualizar o comportamento das séries ao longo do tempo.

# %%
dados[['magalu','petrobras','dolar']].plot(figsize=(12,6))
plt.title("Evolução dos ativos")
plt.show()

# %% [markdown]
# Para complementar a análise exploratória, foi avaliada a distribuição dos dados, permitindo observar a dispersão e o comportamento de cada variável. (histograma)

# %%
dados.hist(figsize=(10,6))
plt.suptitle("Distribuição das variáveis")
plt.show()

# %% [markdown]
# ## 5. Relação entre variáveis
# Finalidade:
#
# Avaliar como as variáveis se relacionam.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dados.corr(), cmap='coolwarm')
plt.title("Matriz de correlação")
plt.show()

# %% [markdown]
# Permite observar possíveis relações diretas ou inversas entre dólar e ações.

# %% [markdown]
# ## 6. Tratamento dos dados
# Finalidade:
#
# Ajustar a escala dos dados para melhorar o desempenho do modelo.

# %%
scaler = MinMaxScaler()
dados_scaled = scaler.fit_transform(dados)

# %% [markdown]
# A padronização evita que valores muito altos influenciem desproporcionalmente o treinamento.

# %% [markdown]
# ## 7. Estruturação para LSTM
# Finalidade:
#
# Organizar os dados em formato sequencial.

# %%
def create_sequences(data, seq_len=30):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len][1])  # magalu
    return np.array(X), np.array(y)

X, y = create_sequences(dados_scaled, 30)

# %% [markdown]
# O modelo passa a considerar histórico recente para realizar previsões.

# %% [markdown]
# ## 8. Separação dos dados

# %%
split = int(0.8 * len(X))

X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# ## 9. Construção do modelo

# %%
model = Sequential()

model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.3))

model.add(LSTM(64))
model.add(Dropout(0.3))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# A arquitetura foi escolhida para capturar padrões complexos sem sobreajuste.

# %% [markdown]
# ## 10. Treinamento

# %%
history = model.fit(
    X_train, y_train,
    epochs=60,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0106 - val_loss: 0.0460
# Epoch 2/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0018 - val_loss: 0.0130
# Epoch 3/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 4/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 9.6947e-04 - val_loss: 8.0268e-04
# Epoch 5/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 9.6538e-04 - val_loss: 0.0037
# Epoch 6/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 7.7837e-04 - val_loss: 0.0021
# Epoch 7/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 7.3249e-04 - val_loss: 0.0032
# Epoch 8/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 6.6171e-04 - val_loss: 0.0022
# Epoch 9/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 6.7257e-04 - val_loss: 0.0033
# Epoch 10/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 6.6067e-04 - val_loss: 0.0072
# Epoch 11/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 5.5297e-04 - val_loss: 0.0048
# Epoch 12/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.8328e-04 - val_loss: 0.0019
# Epoch 13/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 4.5590e-04 - val_loss: 0.0068
# Epoch 14/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.4292e-04 - val_loss: 0.0054
# Epoch 15/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 5.0363e-04 - val_loss: 0.0045
# Epoch 16/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.1592e-04 - val_loss: 0.0043
# Epoch 17/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0551e-04 - val_loss: 0.0037
# Epoch 18/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0964e-04 - val_loss: 0.0044
# Epoch 19/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6786e-04 - val_loss: 0.0041
# Epoch 20/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.7289e-04 - val_loss: 0.0034
# Epoch 21/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.1123e-04 - val_loss: 0.0036
# Epoch 22/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.4856e-04 - val_loss: 0.0054
# Epoch 23/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.7241e-04 - val_loss: 0.0072
# Epoch 24/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.6766e-04 - val_loss: 0.0035
# Epoch 25/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.4086e-04 - val_loss: 0.0038
# Epoch 26/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 3.5507e-04 - val_loss: 0.0029
# Epoch 27/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 3.2681e-04 - val_loss: 0.0024
# Epoch 28/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 3.1266e-04 - val_loss: 0.0056
# Epoch 29/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.8704e-04 - val_loss: 0.0036
# Epoch 30/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.0827e-04 - val_loss: 0.0024
# Epoch 31/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 2.8936e-04 - val_loss: 0.0043
# Epoch 32/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.7118e-04 - val_loss: 0.0038
# Epoch 33/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.5271e-04 - val_loss: 0.0034
# Epoch 34/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.6522e-04 - val_loss: 0.0019
# Epoch 35/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 2.4605e-04 - val_loss: 0.0073
# Epoch 36/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2.8811e-04 - val_loss: 0.0068
# Epoch 37/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.6635e-04 - val_loss: 0.0054
# Epoch 38/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 2.6119e-04 - val_loss: 0.0057
# Epoch 39/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 3.0554e-04 - val_loss: 0.0037
# Epoch 40/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 2.4559e-04 - val_loss: 0.0045
# Epoch 41/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.4186e-04 - val_loss: 0.0031
# Epoch 42/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 2.6736e-04 - val_loss: 0.0027
# Epoch 43/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.3726e-04 - val_loss: 0.0027
# Epoch 44/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 2.2996e-04 - val_loss: 0.0033
# Epoch 45/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2.1365e-04 - val_loss: 0.0059
# Epoch 46/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.3408e-04 - val_loss: 0.0013
# Epoch 47/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.7543e-04 - val_loss: 0.0075
# Epoch 48/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 3.0531e-04 - val_loss: 0.0027
# Epoch 49/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 2.2751e-04 - val_loss: 0.0038
# Epoch 50/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.2306e-04 - val_loss: 0.0026
# Epoch 51/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 2.5939e-04 - val_loss: 0.0015
# Epoch 52/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.0543e-04 - val_loss: 0.0023
# Epoch 53/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 2.1141e-04 - val_loss: 0.0037
# Epoch 54/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 2.2775e-04 - val_loss: 0.0020
# Epoch 55/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 1.9489e-04 - val_loss: 0.0035
# Epoch 56/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.2378e-04 - val_loss: 0.0023
# Epoch 57/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.9984e-04 - val_loss: 0.0013
# Epoch 58/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 2.2449e-04 - val_loss: 0.0011
# Epoch 59/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 2.0476e-04 - val_loss: 0.0028
# Epoch 60/60
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.9266e-04 - val_loss: 0.0035

# %% [markdown]
# ## Gráfico de perda do modelo

# %%
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.legend()
plt.title('Evolução do erro do modelo')
plt.show()

# %% [markdown]
# A evolução do erro durante o treinamento foi analisada para verificar o aprendizado do modelo e identificar possíveis sinais de overfitting.

# %% [markdown]
# ## 11. Avaliação

# %%
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# MAE: 0.08764233421398962
# RMSE: 0.09476783847746383

# %% [markdown]
# ## 12. Visualização

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Real')
plt.plot(y_pred, label='Previsto')
plt.legend()
plt.title("Resultado da previsão")
plt.show()

# %% [markdown]
# ## 13. Discussão dos resultados
#
# Os resultados indicam que o modelo foi capaz de capturar padrões relevantes nas séries temporais analisadas.
#
# Observa-se que a Magazine Luiza apresenta maior volatilidade, o que pode ser explicado pela sua dependência de importações e maior sensibilidade ao dólar.
#
# Em contrapartida, a Petrobras apresenta comportamento mais estável, possivelmente devido à sua atuação no setor de commodities e exposição ao mercado internacional.
#
# Esses resultados reforçam a hipótese inicial de que o impacto do dólar varia de acordo com o setor econômico da empresa.

# %% [markdown]
# ## 14. Considerações finais
#
# A análise mostrou que o impacto do dólar não ocorre de maneira uniforme entre as empresas.
#
# O uso de redes LSTM permitiu identificar padrões relevantes nas séries temporais, especialmente quando combinadas com múltiplas variáveis.
#
# Como continuidade do estudo, seria interessante:
#
# incluir outros indicadores econômicos
# analisar mais empresas
# testar diferentes arquiteturas de modelos
